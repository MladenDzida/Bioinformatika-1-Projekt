# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("../results.txt")
data.head(10)
# Out:
#    per_fill         bits  num_of_insertion_call  num_of_insert  \
# 0  0.093084   29786800.0                 930838         930838
# 1  0.186168   29786800.0                 930838         930838
# 2  0.930838   29786800.0                 934177         930838
# 3  0.539122  172519000.0                5391221        5391221
# 4  1.000000  160000000.0                9490305        5000000
# 5  1.000000   32000000.0               49388872        1000000
# 6  0.543644  173966000.0                5436445        5436445
# 7  1.000000  160000000.0                9985200        5000000
# 8  1.000000   32000000.0               49885341        1000000
# 9  0.546444  174862000.0                5464438        5464438
#
#    length_of_sequence  num_of_buckets  bucket_size   MNK   avg_MNK  \
# 0                  10           10000         1000  1000  0.000000
# 1                  10           10000          500  1000  0.000000
# 2                  10           10000          100    10  0.003587
# ...

# %%
fill = data.loc[data.length_of_sequence == 10]
fill['size'] = data.loc[:, 'num_of_buckets'] * data.loc[:, 'bucket_size']
fill.head(10)
# Out:
# C:\Users\grga\AppData\Local\Temp\ipykernel_16616\657574234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fill['size'] = data.loc[:, 'num_of_buckets'] * data.loc[:, 'bucket_size']
#     per_fill        bits  num_of_insertion_call  num_of_insert  \
# 0   0.093084  29786800.0                 930838         930838
# 1   0.186168  29786800.0                 930838         930838
# 2   0.930838  29786800.0                 934177         930838
# 15  1.000000  16000000.0                5281543         500000
# 16  0.372335  29786800.0                 930838         930838
# 17  1.000000   8000000.0                7760451         250000
#
#     length_of_sequence  num_of_buckets  bucket_size   MNK   avg_MNK  \
# ...

# %%
fill = fill.sort_values(by=['size'])
fill.head(10)
# Out:
#     per_fill        bits  num_of_insertion_call  num_of_insert  \
# 17  1.000000   8000000.0                7760451         250000
# 15  1.000000  16000000.0                5281543         500000
# 2   0.930838  29786800.0                 934177         930838
# 16  0.372335  29786800.0                 930838         930838
# 1   0.186168  29786800.0                 930838         930838
# 0   0.093084  29786800.0                 930838         930838
#
#     length_of_sequence  num_of_buckets  bucket_size   MNK   avg_MNK  \
# 17                  10            2500          100    10  7.337060
# 15                  10            5000          100    10  4.673970
# 2                   10           10000          100    10  0.003587
# 16                  10           25000          100    10  0.000000
# 1                   10           10000          500  1000  0.000000
# 0                   10           10000         1000  1000  0.000000
#
# ...

# %%
plt.plot(fill.loc[:, 'size'], fill.loc[:, 'per_fill'])
plt.xlabel('Size')
plt.ylabel('Fill')
plt.savefig('10_size_per_fill.png')
plt.savefig('10_size_per_fill.svg')

# %%
sb.set_theme()
sb.lineplot(data=fill, x='size', y='per_fill')
# Out:
# <AxesSubplot:xlabel='size', ylabel='per_fill'>

# %%
data['size'] = data.loc[:, 'num_of_buckets'] * data.loc[:, 'bucket_size']
data = data.sort_values(by=['size'])

# %%
sb.lineplot(data=data, x='size', y='row_fill', hue='length_of_sequence', style='length_of_sequence', markers=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='row_fill'>

# %%
sb.lineplot(data=data.loc[data.length_of_sequence == 100], x='size', y='per_fill')
# Out:
# <AxesSubplot:xlabel='size', ylabel='per_fill'>

# %%
def plot(array_1, array_2, data):
    data['size'] = data.loc[:, 'num_of_buckets'] * data.loc[:, 'bucket_size']
    data = data.sort_values(by=['size'])
    data['per_row_fill'] = data.loc[:, 'row_fill'] / data.loc[:, 'num_of_buckets']
    
    for x, y in zip(array_1, array_2):
        plt.figure();
        sb.lineplot(data=data, x=x, y=y, hue='length_of_sequence', style='reduce', markers=True)

array_1 = ['size', 'size']
array_2 = ['per_fill', 'per_row_fill']
plot(array_1, array_2, data.loc[(data.length_of_sequence == 100)])
# Out:
# C:\Users\grga\AppData\Local\Temp\ipykernel_16616\1642336399.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['size'] = data.loc[:, 'num_of_buckets'] * data.loc[:, 'bucket_size']

# %%
sb.lineplot(data=data.loc[data.length_of_sequence == 100], x='size', y='per_fill',  hue='reduce', markers=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 sb.lineplot(data=data.loc[data.length_of_sequence == 100], x='size', y='per_fill',  hue='reduce', markers=True)
#
# File ~\anaconda3\envs\fakultet_DAP_projekt\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
data.loc[data.length_of_sequence == 100]
# Out:
#     per_fill         bits  num_of_insertion_call  num_of_insert  \
# 9   0.546444  174862000.0                5464438        5464438
# 10  1.000000  160000000.0               10296378        5000000
# 11  1.000000   32000000.0               50194795        1000000
# 24  1.000000   16000000.0               55152405         500000
# 25  1.000000   80000000.0               35321566        2500000
# 26  1.000000    8000000.0               57629549         250000
# 30  1.000000   16000000.0               55116523         500000
# 31  1.000000   80000000.0               35148113        2500000
# 32  1.000000    8000000.0               57612676         250000
# 33  1.000000    8000000.0               57612725         250000
# 34  1.000000   80000000.0               35147843        2500000
# 35  1.000000   16000000.0               55116531         500000
#
#     length_of_sequence  num_of_buckets  bucket_size  MNK   avg_MNK  \
# ...
